# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\rku68\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
salary=pd.read_csv(r"C:\Users\rku68\OneDrive\Desktop\csv\Salary_Data.csv")

# %%
salary.head(3)
# Out:
#     Age  Experience  Salary
# 0  21.0         1.1   39343
# 1  21.5         1.3   46205
# 2  21.7         1.5   37731

# %%
salary.shape
# Out:
# (30, 3)

# %%
salary.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.title('year vs salary')
sns.scatterplot(salary['YearsExperience'],salary['Salary'])
plt.subplot(1,2,2)
plt.title('age vs salary')
sns.scatterplot(salary['Age'],salary['Salary'])
plt.show()
# Out:
# C:\Users\rku68\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rku68\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(data=salary)
plt.show()

# %%
sns.heatmap(data=salary.corr(),annot=True)
plt.show()

# %%
x=salary.iloc[:,:-1]
y=salary['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 97.22183267058156

# %%
lr.predict(x_test)
# Out:
# array([ 46293.25826445,  69176.93259935,  75758.71948755, 128929.40911518,
#         62491.86680675, 116793.94721721])

# %%
#y=m1*x1+m2*x2+c

# %%
lr.coef_
# Out:
# array([2159.50266127, 5656.95391417])

# %%
lr.intercept_
# Out:
# -12529.708111770247

# %%
5573.5233818*x1-2100.95219596x2-10844.187410899074
# Out:
#   Input In [20]
#     5573.5233818*x1-2100.95219596x2-10844.187410899074
#                                  ^
# SyntaxError: invalid syntax
