# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv(r"C:\Users\rku68\OneDrive\Desktop\Data Science\Machine Learning\Non-Linear Supervised Algorithm in Machine Learning\irisraw.csv")

# %%
iris.head(3)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2

# %%
#sns.pairplot(iris)
#plt.show()

# %%
import scipy.cluster.hierarchy as sc

# %%
plt.figure(figsize=(20,5))
sc.dendrogram(sc.linkage(iris,method='single',metric='euclidean'))
plt.savefig('demo1.jpg')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ac=AgglomerativeClustering(n_clusters=2,linkage='single')
iris['predict']=ac.fit_predict(iris)

# %%
iris.head(2)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  predict
# 0            5.1           3.5            1.4           0.2        1
# 1            4.9           3.0            1.4           0.2        1

# %%
sns.pairplot(iris,hue='predict')
plt.show()
